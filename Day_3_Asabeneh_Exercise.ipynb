# %% [markdown]
# <a href="https://colab.research.google.com/github/Dznnm/chode_in_hand/blob/main/Day_3_Asabeneh_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age=25

# %%
print('age:',age,)
# Out:
# age: 25

# %%
print('age type:',type(age))
# Out:
# age type: <class 'int'>

# %%
height=1.62

# %%
print(height)
# Out:
# 1.62

# %%
print('height type:',type(height))
# Out:
# height type: <class 'float'>

# %%
imaj=25+2J

# %%
print(imaj)
# Out:
# (25+2j)

# %%
print('imaj type:',type(imaj))
# Out:
# imaj type: <class 'complex'>

# %%
#Script that prompts the user to enter base and height and calculate area

# %%
base_int=input('Enter base length:')
# Out:
# Enter base length:20

# %%
height_int=input('Enter height length:')
# Out:
# Enter height length:10

# %%
print('Area of Triangle:',tri_area=0.5*base_int*height_int)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1270/1121277662.py in <cell line: 0>()
# ----> 1 print('Area of Triangle:',tri_area=0.5*base_int*height_int)
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
float(height_int)
# Out:
# 10.0

# %%
float(base_int)
# Out:
# 20.0

# %%
type(base_int)
# Out:
# str

# %%
tri_area=0.5*float(base_int)*float(height_int)

# %%
print(tri_area)
# Out:
# 100.0

# %%
print('The area of the triangle:',tri_area)
# Out:
# The area of the triangle: 100.0

# %%
#Write a script that prompts the user to enter side a, side b, and side c of the triangle. Calculate the perimeter of the triangle (perimeter = a + b + c).

# %%
side_a=input('side a:')
# Out:
# side a:5

# %%
side_b=input('side b:')
# Out:
# side b:4

# %%
side_c=input('side c:')
# Out:
# side c:3

# %%
side_a=int(side_a)

# %%
side_b=int(side_b)

# %%
side_c=int(side_c)

# %%
perimeter_abc=side_a+side_b+side_c

# %%
print(perimeter_abc)
# Out:
# 12

# %%
print('The perimeter of the triangle is',perimeter_abc)
# Out:
# The perimeter of the triangle is 12

# %%
length_rec=input('Length of rectangle:')
# Out:
# Length of rectangle:8

# %%
width_rec=input('Width of rectangle:')
# Out:
# Width of rectangle:6

# %%
area_rec=float(length_rec)*float(width_rec)

# %%
perim_rec=2*(float(length_rec)+float(width_rec))

# %%
print('Area of rectangle is',area_rec)
# Out:
# Area of rectangle is 48.0

# %%
print('Perimeter of rectangle is',perim_rec)
# Out:
# Perimeter of rectangle is 28.0

# %%
#Radius of circle, Area, and Circumference

# %%
rad_circ=input('Radius of circle:')
# Out:
# Radius of circle:12

# %%
pi=22/7

# %%
print('Value of pi:',float(pi))
# Out:
# Value of pi: 3.142857142857143

# %%
float(rad_circ)
# Out:
# 12.0

# %%
area_circ=pi*rad_circ**2

# %%
rad_circ=float(rad_circ)

# %%
circum_circ=2*pi*rad_circ

# %%
print('Area of Circle is',area_circ)
# Out:
# Area of Circle is 452.57142857142856

# %%
print('Circumference of circle is', circum_circ)
# Out:
# Circumference of circle is 75.42857142857143

# %%
#Calculate the slope, x-intercept, y-intercept of y=2x-2

# %%
m=2

# %%
slope=m

# %%
print('Slope =',m)
# Out:
# Slope = 2

# %%
print('slope, x_int,y_int')
# Out:
# slope, x_int,y_int

# %%
print('slope = m')
# Out:
# slope = m

# %%
print('y_int = b')
# Out:
# y_int = b

# %%
print('x_int = -b/m')
# Out:
# x_int = -b/m

# %%
slope=m

# %%
y_int=b

# %%
m=2

# %%
b=-2

# %%
x_int=-b/m

# %%
print('Slope =',slope)
# Out:
# Slope = 2

# %%
print('y_int =',y_int)
# Out:
# y_int = -2

# %%
print('x_int =',x_int)
# Out:
# x_int = 1.0

# %%
del m

# %%
m1=2

# %%
x1,y1=2,2

# %%
x2,y2=6,10

# %%
print('point 1: (2,2)')
# Out:
# point 1: (2,2)

# %%
print('point 2: (6,10)')
# Out:
# point 2: (6,10)

# %%
m2=(y2-y1)/(x2-x1)

# %%
print('m2 = y2-y1/x2-x1 =',m2)
# Out:
# m2 = y2-y1/x2-x1 = 2.0

# %%
#Comparing slopes of 2 tasks

# %%
print('m1 = m2', m1==m2)
# Out:
# m1 = m2 True

# %%
print('m1 != m2 :',m1!=m2)
# Out:
# m1 != m2 : False

# %%
print('m1 > m2:',m1>m2)
# Out:
# m1 > m2: False

# %%
print('m1 < m2:',m1<m2)
# Out:
# m1 < m2: False

# %%
print('m1 >= m2:',m1>=m2)
# Out:
# m1 >= m2: True

# %%
print('m1 is m2:',m1 is m2)
# Out:
# m1 is m2: False

# %%
#(y = x^2 + 6x +9) Calculate the value of y. use diff x values for y = 0

# %%
x=input('Value of X:')
# Out:
# Value of X:-3

# %%
x=float(x)

# %%
y=x**2+6*x+9

# %%
print('y =',y)
# Out:
# y = 0.0

# %%
print('y = 0 when x = -3')
# Out:
# y = 0 when x = -3

# %%
print(len(python))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3384/2676952547.py in <cell line: 0>()
# ----> 1 print(len(python))
#
# NameError: name 'python' is not defined

# %%
print(len('python'))
# Out:
# 6

# %%
print('Length of word python:',len('python'))
# Out:
# Length of word python: 6

# %%
print('Length of word dragon:',len('dragon'))
# Out:
# Length of word dragon: 6

# %%
print('python and dragon are not the same length:'),len('python')!=len('dragon')
# Out:
# python and dragon are not the same length:
# (None, False)

# %%
6!=6
# Out:
# False

# %%
len('python')!=len('dragon')
# Out:
# False

# %%
print('python and dragon are not the same length:',len('python')!=len('dragon'))
# Out:
# python and dragon are not the same length: False

# %%
1 in (1,2,3,4,5)
# Out:
# True

# %%
print('on is in both python and dragon:','on' in 'python' and 'on' in 'dragon')
# Out:
# on is in both python and dragon: True

# %%
'on' in 'python'
# Out:
# True

# %%
'on' in 'dragon'
# Out:
# True

# %%
'on' in 'python' and 'dragon'
# Out:
# 'dragon'

# %%
print('jargon is in the sentence I hope this course is not full of jargon:', 'jargon' in 'i hope this course is not full of jargon')
# Out:
# jargon is in the sentence I hope this course is not full of jargon: True

# %%
'on' in 'python and dragon'
# Out:
# True

# %%
print('there is no on in both dragon and python:','on' not in 'python' and 'on' not in 'dragon')
# Out:
# there is no on in both dragon and python: False

# %%
print('length of word python:',len('python'))
# Out:
# length of word python: 6

# %%
print('length of python to float:',float(len('python')))
# Out:
# length of python to float: 6.0

# %%
print('length of word python to float to string:',str(float(len('python'))))
# Out:
# length of word python to float to string: 6.0

# %%
print(3/2)
# Out:
# 1.5

# %%
2 is even
# Out:
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# /tmp/ipykernel_3384/718849894.py:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   2 is even
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3384/718849894.py in <cell line: 0>()
# ----> 1 2 is even
#
# NameError: name 'even' is not defined

# %%
3%2
# Out:
# 1

# %%
3%2==0
# Out:
# False

# %%
#how to know if number is even (because even number if div by 2 remainder is 0)

# %%
print('7 is even:',7%2==0)
# Out:
# 7 is even: False

# %%
print('6 is even:',6%2==0)
# Out:
# 6 is even True

# %%
6//2
# Out:
# 3

# %%
6/3
# Out:
# 2.0

# %%
print('floor division of 7 by 3 equal to int conversion of 2.7:',7//3==int(2.7))
# Out:
# floor division of 7 by 3 equal to int conversion of 2.7: True

# %%
print('floor division of 7 by 3:',7//3)
# Out:
# floor division of 7 by 3: 2

# %%
print('int conversion of 2.7:',int(2.7))
# Out:
# int conversion of 2.7: 2

# %%
print("type of '10' equal to type of 10:",type('10')==type(10))
# Out:
# type of '10' equal to type of 10: False

# %%
print("int('9.8) is equal to 10:",int(float('9.8'))==10)
# Out:
# int('9.8) is equal to 10: False

# %%
print("int'9.8':",int(float('9.8')))
# Out:
# int'9.8': 9

# %%
#Enter hours and rate/hour to calculate pay of person

# %%
work_hours=input('Enter hours: ')
# Out:
# Enter hours: 73.5

# %%
rate_per_hour=input('rate per hour: ')
# Out:
# rate per hour: 31250

# %%
print('Your weekly earning is:',float(work_hours)*float(rate_per_hour))
# Out:
# Your weekly earning is: 2296875.0

# %%
#enter number of years to calculate number of seconds can live, assume 100 years to live

# %%
years_lived=input('Enter number of years you have lived: ')
# Out:
# Enter number of years you have lived: 25

# %%
seconds_lived=365*24*60*60*float(years_lived)

# %%
print('You have lived for:',seconds_lived,'seconds')
# Out:
# You have lived for: 788400000.0 seconds

# %%
years_left=100-float(years_lived)

# %%
print('Years to live left:',years_left)
# Out:
# Years to live left: 75.0

# %%
seconds_left=365*24*60*60*years_left

# %%
print('Seconds to live left:',int(seconds_left),'seconds')
# Out:
# Seconds to live left: 2365200000 seconds

# %%
#making a table?

# %%
print(1,1,1,1,1)
print(2,1,2,4,8)
print(3,1,3,9,27)
print(4,1,4,16,64)
print(5,1,5,25,125)
# Out:
# 1 1 1 1 1
# 2 1 2 4 8
# 3 1 3 9 27
# 4 1 4 16 64
# 5 1 5 25 125

# %%
#asabeneh day 3 tasks done

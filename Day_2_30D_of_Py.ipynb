# %% [markdown]
# <a href="https://colab.research.google.com/github/Dznnm/chode_in_hand/blob/main/Day_2_30D_of_Py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
first_name='Dzannun'

# %%
last_name='Muhlashon'

# %%
full_name='Dzannun Muhlashon'

# %%
country='Indonesia'

# %%
city='Jakarta Timur'

# %%
age='25'

# %%
year='2026'

# %%
is_married=False

# %%
is_true='Likes to gym'

# %%
is_light='Chips'

# %%
print('What is your full name:',first_name,last_name)
# Out:
# What is your full name: Dzannun Muhlashon

# %%
print('What is your full name and spell it:',first_name,last_name,list(full_name))
# Out:
# What is your full name and spell it: Dzannun Muhlashon ['D', 'z', 'a', 'n', 'n', 'u', 'n', ' ', 'M', 'u', 'h', 'l', 'a', 's', 'h', 'o', 'n']

# %%
print('Country of origin:',country)
# Out:
# Country of origin: Indonesia

# %%
print('Duration on this land:',age)
# Out:
# Duration on this land: 25

# %%
print('current time of this land:',year)
# Out:
# current time of this land: 2026

# %%
print('is the writer married?', is_married)
# Out:
# is the writer married? False

# %%
print('then what is true?', is_true)
# Out:
# then what is true? Likes to gym

# %%
print('thats heavy, what is something light:', is_light)
# Out:
# thats heavy, what is something light: Chips

# %%
type(first_name)
# Out:
# str

# %%
len(first_name)
# Out:
# 7

# %%
len(full_name)
# Out:
# 17

# %%
len(last_name)
# Out:
# 9

# %%
num_one=7

# %%
num_two=9

# %%
print(num_one + num_two)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_66236/1037308713.py in <cell line: 0>()
# ----> 1 print(sum(num_one,num_two))
#
# TypeError: 'int' object is not iterable

# %%
type(num_one)
# Out:
# int

# %%
print(num_one+num_two)
# Out:
# 16

# %%
num_sum=num_one+num_two

# %%
print(num_sum)
# Out:
# 16

# %%
num_diff=num_one-num_two

# %%
print(num_diff)
# Out:
# -2

# %%
print(num_one*num_two)
# Out:
# 63

# %%
num_prod=num_one*num_two

# %%
print(num_prod)
# Out:
# 63

# %%
print(num_one/num_two)
# Out:
# 0.7777777777777778

# %%
num_div=num_one/num_two

# %%
print(num_diff)
# Out:
# -2

# %%
print(num_div)
# Out:
# 0.7777777777777778

# %%
num_mod = num_one % num_two
print('Modulus of num_one by num_two:', num_mod)

# %%
num_mod=num_two%num_one

# %%
print(num_mod)
# Out:
# 2

# %%
del num_mod

# %%
num_rem=num_two%num_one

# %%
print(num_rem)
# Out:
# 2

# %%
num_exp=num_one**num_two

# %%
print(num_exp)
# Out:
# 40353607

# %%
num_floor_div = num_one // num_two
print('Floor division of num_one by num_two:', num_floor_div)

# %%
floor_div=num_two//num_one

# %%
print(floor_div)
# Out:
# 1

# %%
r=30

# %%
import math

# %%
print('The value of pi is:', math.pi)

# %%
pi=22/7

# %%
circ_area=pi*r**2

# %%
print(circ_area)
# Out:
# 2828.5714285714284

# %%
circ_circum=2*pi*r

# %%
print(pi)
# Out:
# 3.142857142857143

# %%
print(circ_circum)
# Out:
# 188.57142857142856

# %%
del r

# %%
r=input('Radius of Circle:')
# Out:
# Radius of Circle:20

# %%
print(circ_area)
# Out:
# 2828.5714285714284

# %%
del circ_area

# %%
circ_area=pi*r**2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_66236/385184459.py in <cell line: 0>()
# ----> 1 circ_area=pi*r**2
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str' and 'int'

# %%
print(r)
# Out:
# 20

# %%
type(r)
# Out:
# str

# %%
del r

# %%
r=int(input('Radius of Circle:'))
# Out:
# Radius of Circle:20

# %%
circ_area=pi*r**2

# %%
print(circ_area)
# Out:
# 1257.142857142857

# %%
r
# Out:
# 20

# %%
circ_circum
# Out:
# 188.57142857142856

# %%
circ_circum=2*pi*r

# %%
circ_circum
# Out:
# 125.71428571428571

# %%
circ_area
# Out:
# 1257.142857142857

# %% [markdown]
# DAY 2 DONE WE HAVE CIRC_AREA AND CIRC_CICRUM
